# %% [markdown]
# <a href="https://colab.research.google.com/github/Prithvi-Satish/FlyRank-Project/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""freestyle-prediction of web page momentum/activity

This lane questions the relevance and performance of client web pages. Solving this problem and predicting which pages are likely to decline,recover or gain momentum will help web page reviewers to
decide which pages need immediate attention and revamping, and which they only need to maintain or monitor activity. It will help content reviewers be more effective and improve client web page
productivity."""
# Out:
# 'freestyle-prediction of web page momentum/activity\n\nThis lane questions the relevance and performance of client web pages. Solving this problem and predicting which pages are likely to decline,recover or gain momentum will help web page reviewers to\ndecide which pages need immediate attention and revamping, and which they only need to maintain or monitor activity. It will help content reviewers be more effective and improve client web page\nproductivity.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""This work will help content reviwers make decisions about which pages require review and get editors to refresh the pages in a systemic way from most urgent to least.
The editors will act on this data and they will review the top web pages and refresh SEO/images/copy etc.
If the recommendation is wrong then it can lead to wasted time of the editor or unnecessary changes to website which can affect future performance or if it wrongly predicts low performance as
optimal it can lead to missed traffic and customer footfall and eventually lost revenue."""
# Out:
# 'This work will help content reviwers make decisions about which pages require review and get editors to refresh the pages in a systemic way from most urgent to least.\nThe editors will act on this data and they will review the top web pages and refresh SEO/images/copy etc. \nIf the recommendation is wrong then it can lead to wasted time of the editor or unnecessary changes to website which can affect future performance or if it wrongly predicts low performance as\noptimal it can lead to missed traffic and customer footfall and eventually lost revenue.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("content_refresh_anonymized.csv")
print("unique clients:", df["client_id"].nunique())
print("is_declining_label distribution:")
print(df["trend_direction"].value_counts(dropna=False).to_string())
print("avg ctr (mean):", df["ctr"].mean())
print("avg_position==0 (rows with no position data):", df["avg_position"].eq(0).sum())
missing = df.isna().mean().sort_values(ascending=False).head(8)
print("top missingness (cols):")
print(missing.to_string())
# Out:
# unique clients: 32
# is_declining_label distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# avg ctr (mean): 0.5107333333333334
# avg_position==0 (rows with no position data): 1205
# top missingness (cols):
# provider_used        0.714600
# word_count           0.256633
# char_count           0.256633
# word_count_tier      0.256633
# char_count_tier      0.256633
# model_used           0.191100
# trend_pct            0.112933
# competition_level    0.087000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("We will be able to successfully predict page relevance and performance over\ntrend relevant timeframes and even provide editors with actionable data for example a usually\nwell performing item is predicted to decline over the next 30 days so editors can\npre-emptively work on refreshing it with new SEO parameters,redesigns etc.\nWe cannot claim causal effects with these recommendations as without experimentation or\nsome type of benchmarking we cannot boil down to say that the page revived due to\nintervention based on recommendation nor can we claim performance beyond the test window")
# Out:
# We will be able to successfully predict page relevance and performance over
# trend relevant timeframes and even provide editors with actionable data for example a usually
# well performing item is predicted to decline over the next 30 days so editors can
# pre-emptively work on refreshing it with new SEO parameters,redesigns etc.
# We cannot claim causal effects with these recommendations as without experimentation or
# some type of benchmarking we cannot boil down to say that the page revived due to
# intervention based on recommendation nor can we claim performance beyond the test window

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
